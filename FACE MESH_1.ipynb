# %%
import cv2
import mediapipe as mp
import time

# %%
pip install mediapipe
# Out:
# ...
#   Obtaining dependency information for mediapipe from https://files.pythonhosted.org/packages/da/f9/393618415e43f76a694ce8d1c8147ed0ec5f05cecc6cab2e02dcb4a0bc3f/mediapipe-0.10.7-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/162.1 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.1 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.1 kB ? eta -:--:--
#      --------- --------------------------- 41.0/162.1 kB 326.8 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/162.1 kB 573.4 kB/s eta 0:00:01
#      ------------------------------------ 162.1/162.1 kB 883.1 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/199.7 kB ? eta -:--:--
#      --------------- ----------------------- 81.9/199.7 kB 4.5 MB/s eta 0:00:01
#      -------------------------------------- 199.7/199.7 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/50.3 MB ? eta -:--:--
# ...

# %%
# cap= cv2.VideoCapture(r'C:\Users\kdata\Desktop\KODI WORK\0. DATASCIENCE PROJECT\29. Mediapipe\facemesh\w.mp4')
cap = cv2.VideoCapture(0)  # Open the default camera (usually webcam)
if not cap.isOpened():
    print("Error: Could not open the camera.")
#     break  
    # Exit the loop or handle the error as needed

# %%
pTime =0
mpDraw= mp.solutions.drawing_utils
mpFaceMesh=mp.solutions.face_mesh
faceMesh=mpFaceMesh.FaceMesh(max_num_faces=1)

# %%
while True:
    success , img =cap.read()
    if not success:
        break  # Exit the loop if there are no more frames to read
    
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results=faceMesh.process(imgRGB)
    if results.multi_face_landmarks:
        for faceLms in results.multi_face_landmarks:
          mpDraw.draw_landmarks(img,faceLms, mpFaceMesh.FACEMESH_TESSELATION)
   
    cTime = time.time()
    fps = 1 / (cTime - pTime)
    pTime = cTime

    cv2.putText(img, f'FPS: {int(fps)}', (20, 70), cv2.FONT_HERSHEY_PLAIN, 3, (0, 255, 0), 3)

    cv2.imshow("image", img)
    
    cv2.waitKey(1)
