# %%
import pandas as pd

# %%
my_data = pd.read_excel(r"C:\Users\M GNANESHWARI\Documents\TASK -- convert raw data - clean data.xlsx")
my_data
# Out:
#                  Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                       NaN         NaN         NaN         NaN         NaN
# 1                       NaN         NaN         NaN         NaN         NaN
# 2                       NaN         NaN         NaN         NaN         NaN
# 3                       NaN         NaN         NaN         NaN         NaN
# 4                       NaN         NaN         NaN         NaN         NaN
# 5                       NaN         NaN         NaN         NaN         NaN
# 6                       NaN         NaN         NaN         NaN         NaN
# 7                       NaN         NaN         NaN         NaN         NaN
# 8                       NaN         NaN         NaN         NaN         NaN
# 9                       NaN         NaN         NaN         NaN         NaN
# 10                      NaN         NaN         NaN         NaN         NaN
# ...

# %%
raw_data=my_data
raw_data
# Out:
#                  Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                       NaN         NaN         NaN         NaN         NaN
# 1                       NaN         NaN         NaN         NaN         NaN
# 2                       NaN         NaN         NaN         NaN         NaN
# 3                       NaN         NaN         NaN         NaN         NaN
# 4                       NaN         NaN         NaN         NaN         NaN
# 5                       NaN         NaN         NaN         NaN         NaN
# 6                       NaN         NaN         NaN         NaN         NaN
# 7                       NaN         NaN         NaN         NaN         NaN
# 8                       NaN         NaN         NaN         NaN         NaN
# 9                       NaN         NaN         NaN         NaN         NaN
# 10                      NaN         NaN         NaN         NaN         NaN
# ...

# %%
DT=list(raw_data.DT)
DT
# Out:
# [Timestamp('2022-04-03 00:00:00'),
#  Timestamp('2022-04-02 00:00:00'),
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT]

# %%
raw_data=pd.DataFrame(my_data)
raw_data
# Out:
#                  Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                       NaN         NaN         NaN         NaN         NaN
# 1                       NaN         NaN         NaN         NaN         NaN
# 2                       NaN         NaN         NaN         NaN         NaN
# 3                       NaN         NaN         NaN         NaN         NaN
# 4                       NaN         NaN         NaN         NaN         NaN
# 5                       NaN         NaN         NaN         NaN         NaN
# 6                       NaN         NaN         NaN         NaN         NaN
# 7                       NaN         NaN         NaN         NaN         NaN
# 8                       NaN         NaN         NaN         NaN         NaN
# 9                       NaN         NaN         NaN         NaN         NaN
# 10                      NaN         NaN         NaN         NaN         NaN
# ...

# %%
# Drop row that has all NaN values
raw_data=raw_data.dropna(how='all')
raw_data
# Out:
#                  Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                       NaN         NaN         NaN         NaN         NaN
# 1                       NaN         NaN         NaN         NaN         NaN
# 20  THIS IS NOT CLEAN DATA          NaN         NaN         NaN         NaN
# 22      THIS IS CLEAN DATA          NaN         NaN         NaN         NaN
#
#     Unnamed: 5                                         ADDR         DT NAME  \
# 0          NaN  45 rd, kenith street, btm, bangalore 500038 2022-04-03  abc
# 1          NaN            45 rd,  street, hitech, Hd 500038 2022-04-02  dec
# 20         NaN                                          NaN        NaT  NaN
# 22         NaN                                          NaN        NaT  NaN
#
#        time
# 0   8:30:21
# 1   5:30:21
# 20      NaN
# 22      NaN

# %%
raw_data=raw_data.dropna(how='all',axis=1)
raw_data
# Out:
#                  Unnamed: 0                                         ADDR  \
# 0                       NaN  45 rd, kenith street, btm, bangalore 500038
# 1                       NaN            45 rd,  street, hitech, Hd 500038
# 20  THIS IS NOT CLEAN DATA                                           NaN
# 22      THIS IS CLEAN DATA                                           NaN
#
#            DT NAME     time
# 0  2022-04-03  abc  8:30:21
# 1  2022-04-02  dec  5:30:21
# 20        NaT  NaN      NaN
# 22        NaT  NaN      NaN

# %%
""""raw_data=raw_data.fillna(0)
raw_data""''
# Out:
#                  Unnamed: 0                                         ADDR  \
# 0                         0  45 rd, kenith street, btm, bangalore 500038
# 1                         0            45 rd,  street, hitech, Hd 500038
# 20  THIS IS NOT CLEAN DATA                                             0
# 22      THIS IS CLEAN DATA                                             0
#
#                      DT NAME     time
# 0   2022-04-03 00:00:00  abc  8:30:21
# 1   2022-04-02 00:00:00  dec  5:30:21
# 20                    0    0        0
# 22                    0    0        0

# %%
unnamed_cols  =  raw_data.columns.str.contains('Unnamed')
unnamed_cols
# Out:
# array([ True, False, False, False, False])

# %%
raw_data = raw_data.drop(raw_data[raw_data.columns[unnamed_cols]], axis=1)

raw_data
# Out:
#                                            ADDR         DT NAME     time
# 0   45 rd, kenith street, btm, bangalore 500038 2022-04-03  abc  8:30:21
# 1             45 rd,  street, hitech, Hd 500038 2022-04-02  dec  5:30:21
# 20                                          NaN        NaT  NaN      NaN
# 22                                          NaN        NaT  NaN      NaN

# %%
# Drop row that has all NaN values
raw_data=raw_data.dropna(how='all',axis=0)
raw_data
# Out:
#                                           ADDR         DT NAME     time
# 0  45 rd, kenith street, btm, bangalore 500038 2022-04-03  abc  8:30:21
# 1            45 rd,  street, hitech, Hd 500038 2022-04-02  dec  5:30:21

# %%
DT=list(raw_data.DT)
DT
# Out:
# [Timestamp('2022-04-03 00:00:00'), Timestamp('2022-04-02 00:00:00')]

# %%
raw_data.DT[0]
# Out:
# Timestamp('2022-04-03 00:00:00')

# %%
DT[0].month
# Out:
# 4

# %%
day=[]
month=[]
year=[]
from datetime import datetime
ld=len(DT) 
for i in DT:
    day.append(i.day)
    month.append(i.month)
    year.append(i.year) 
print(day)
print(month)
print(year)
# Out:
# [3, 2]
# [4, 4]
# [2022, 2022]

# %%
raw_data['Day']=day
raw_data['Month']=month
raw_data['Year']=year
print(raw_data)
# Out:
#                                           ADDR         DT NAME     time  year  \
# 0  45 rd, kenith street, btm, bangalore 500038 2022-04-03  abc  8:30:21  2022
# 1            45 rd,  street, hitech, Hd 500038 2022-04-02  dec  5:30:21  2022
#
#    month  day  hour  minute  Day  Month  Year
# 0      4    3     0       0    3      4  2022
# 1      4    2     0       0    2      4  2022
# C:\Users\M GNANESHWARI\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\M GNANESHWARI\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
ADDR = list(raw_data.ADDR)
ADDR
# Out:
# ['45 rd, kenith street, btm, bangalore 500038',
#  '45 rd,  street, hitech, Hd 500038']

# %%
hnum=[]
street=[]
area=[]
city_zip=[]

for i in ADDR:
    a=i.split(",")
    hnum.append(a[0])
    street.append(a[1])
    area.append(a[2])
    city_zip.append(a[3])
    #print (a)
print(hnum)
print(street)
print(area)
print(city_zip)
# Out:
# ['45 rd', '45 rd']
# [' kenith street', '  street']
# [' btm', ' hitech']
# [' bangalore 500038', ' Hd 500038']

# %%
raw_data['HNO']=hnum
raw_data['Street']=street
raw_data['Area']=area
raw_data['City_Zip']=city_zip
print(raw_data)
# Out:
#                                           ADDR         DT NAME     time  year  \
# 0  45 rd, kenith street, btm, bangalore 500038 2022-04-03  abc  8:30:21  2022
# 1            45 rd,  street, hitech, Hd 500038 2022-04-02  dec  5:30:21  2022
#
#    month  day  hour  minute  Day  Month  Year    HNO          Street     Area  \
# 0      4    3     0       0    3      4  2022  45 rd   kenith street      btm
# 1      4    2     0       0    2      4  2022  45 rd          street   hitech
#
#             City_Zip
# 0   bangalore 500038
# 1          Hd 500038
# C:\Users\M GNANESHWARI\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# ...

# %%
city=[]
zipcode=[]

for i in city_zip:
    a=i.split()
    city.append(a[0])
    zipcode.append(a[1])
  
    #print (a)
print(city)
print(zipcode)
# Out:
# ['bangalore', 'Hd']
# ['500038', '500038']

# %%
raw_data['City']=city
raw_data['Zip_Code']=zipcode
raw_data
# Out:
# C:\Users\M GNANESHWARI\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\M GNANESHWARI\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                           ADDR         DT NAME     time  year  \
# 0  45 rd, kenith street, btm, bangalore 500038 2022-04-03  abc  8:30:21  2022
# ...

# %%
cleansing_data=data
cleansing_data
