# %%
##### Audio Classification Using Machine Learning
#####dataset url https://urbansounddataset.weebly.com/urbansound8k.html

# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.10.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from librosa) (1.12.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from librosa) (1.4.1.post1)
# Requirement already satisfied: joblib>=0.14 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from librosa) (5.1.1)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.59.1-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Collecting soundfile>=0.12.1 (from librosa)
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl.metadata (14 kB)
# Collecting pooch>=1.0 (from librosa)
#   Downloading pooch-1.8.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.3.7-cp310-cp310-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from librosa) (4.9.0)
# Collecting lazy-loader>=0.1 (from librosa)
#   Downloading lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.0.8-cp310-cp310-win_amd64.whl.metadata (9.4 kB)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.42.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from pooch>=1.0->librosa) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from pooch>=1.0->librosa) (23.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from scikit-learn>=0.20.0->librosa) (3.4.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gnaneshwari\.conda\envs\tensorflow_env\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2024.2.2)
# Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#    ---------------------------------------- 0.0/253.7 kB ? eta -:--:--
#    -------------------------------------- - 245.8/253.7 kB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 253.7/253.7 kB 3.9 MB/s eta 0:00:00
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Downloading msgpack-1.0.8-cp310-cp310-win_amd64.whl (75 kB)
#    ---------------------------------------- 0.0/75.1 kB ? eta -:--:--
#    ---------------------------------------- 75.1/75.1 kB ? eta 0:00:00
# Downloading numba-0.59.1-cp310-cp310-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------ --------------------- 1.2/2.7 MB 26.1 MB/s eta 0:00:01
#    ------------------------------------ --- 2.5/2.7 MB 31.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 24.4 MB/s eta 0:00:00
# Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/63.0 kB ? eta -:--:--
#    ---------------------------------------- 63.0/63.0 kB ? eta 0:00:00
# Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ------------------------------------- -- 1.0/1.0 MB 30.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 21.3 MB/s eta 0:00:00
# Downloading soxr-0.3.7-cp310-cp310-win_amd64.whl (184 kB)
#    ---------------------------------------- 0.0/184.6 kB ? eta -:--:--
#    ---------------------------------------- 184.6/184.6 kB ? eta 0:00:00
# Downloading llvmlite-0.42.0-cp310-cp310-win_amd64.whl (28.1 MB)
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    - -------------------------------------- 1.1/28.1 MB 36.7 MB/s eta 0:00:01
#    -- ------------------------------------- 1.6/28.1 MB 21.0 MB/s eta 0:00:02
#    --- ------------------------------------ 2.1/28.1 MB 16.8 MB/s eta 0:00:02
#    --- ------------------------------------ 2.3/28.1 MB 18.1 MB/s eta 0:00:02
#    --- ------------------------------------ 2.3/28.1 MB 18.1 MB/s eta 0:00:02
#    --- ------------------------------------ 2.4/28.1 MB 9.1 MB/s eta 0:00:03
#    --- ------------------------------------ 2.8/28.1 MB 9.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.9/28.1 MB 11.4 MB/s eta 0:00:03
#    ------ --------------------------------- 4.3/28.1 MB 10.9 MB/s eta 0:00:03
#    ------ --------------------------------- 4.8/28.1 MB 11.0 MB/s eta 0:00:03
#    ------- -------------------------------- 5.6/28.1 MB 12.0 MB/s eta 0:00:02
#    -------- ------------------------------- 6.1/28.1 MB 11.9 MB/s eta 0:00:02
#    --------- ------------------------------ 6.6/28.1 MB 12.1 MB/s eta 0:00:02
#    --------- ------------------------------ 6.6/28.1 MB 12.1 MB/s eta 0:00:02
#    --------- ------------------------------ 6.6/28.1 MB 12.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 7.1/28.1 MB 10.3 MB/s eta 0:00:03
#    ------------ --------------------------- 8.9/28.1 MB 12.1 MB/s eta 0:00:02
#    ------------- -------------------------- 9.4/28.1 MB 12.3 MB/s eta 0:00:02
#    -------------- ------------------------- 10.0/28.1 MB 12.3 MB/s eta 0:00:02
#    --------------- ------------------------ 10.6/28.1 MB 12.1 MB/s eta 0:00:02
#    --------------- ------------------------ 11.1/28.1 MB 11.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 11.7/28.1 MB 11.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 12.2/28.1 MB 11.7 MB/s eta 0:00:02
#    ------------------ --------------------- 12.7/28.1 MB 14.2 MB/s eta 0:00:02
#    ------------------ --------------------- 13.3/28.1 MB 13.6 MB/s eta 0:00:02
#    ------------------- -------------------- 13.8/28.1 MB 13.1 MB/s eta 0:00:02
#    -------------------- ------------------- 14.3/28.1 MB 13.1 MB/s eta 0:00:02
#    --------------------- ------------------ 14.8/28.1 MB 13.4 MB/s eta 0:00:01
#    --------------------- ------------------ 15.4/28.1 MB 12.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 15.9/28.1 MB 13.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 16.5/28.1 MB 13.1 MB/s eta 0:00:01
#    ------------------------ --------------- 17.0/28.1 MB 14.9 MB/s eta 0:00:01
#    ------------------------- -------------- 17.6/28.1 MB 14.9 MB/s eta 0:00:01
#    ------------------------- -------------- 18.1/28.1 MB 14.2 MB/s eta 0:00:01
#    -------------------------- ------------- 18.7/28.1 MB 13.4 MB/s eta 0:00:01
#    --------------------------- ------------ 19.3/28.1 MB 12.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 19.9/28.1 MB 12.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 20.4/28.1 MB 13.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 21.0/28.1 MB 12.9 MB/s eta 0:00:01
#    ------------------------------ --------- 21.6/28.1 MB 13.1 MB/s eta 0:00:01
#    ------------------------------- -------- 22.1/28.1 MB 12.8 MB/s eta 0:00:01
#    -------------------------------- ------- 22.6/28.1 MB 12.9 MB/s eta 0:00:01
#    -------------------------------- ------- 23.1/28.1 MB 12.6 MB/s eta 0:00:01
#    --------------------------------- ------ 23.7/28.1 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 24.2/28.1 MB 12.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.8/28.1 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------ --- 25.5/28.1 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------- -- 26.2/28.1 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------- -- 26.7/28.1 MB 12.8 MB/s eta 0:00:01
#    -------------------------------------- - 27.2/28.1 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------  27.7/28.1 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 12.1 MB/s eta 0:00:00
# Installing collected packages: soxr, msgpack, llvmlite, lazy-loader, audioread, soundfile, pooch, numba, librosa
# Successfully installed audioread-3.0.1 lazy-loader-0.3 librosa-0.10.1 llvmlite-0.42.0 msgpack-1.0.8 numba-0.59.1 pooch-1.8.1 soundfile-0.12.1 soxr-0.3.7

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
os.chdir('D:/UrbanSound8K/audio')

# %%
filename=r"D:\UrbanSound8K\audio\fold10\2937-1-0-0.wav"

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
# !dir
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is C09B-7E10
#
#  Directory of D:\UrbanSound8K\audio
#
# 05/20/2014  12:43 AM    <DIR>          .
# 03/26/2024  03:40 PM    <DIR>          ..
# 05/20/2014  12:28 AM            24,580 .DS_Store
# 05/20/2014  12:30 AM    <DIR>          fold1
# 05/20/2014  12:31 AM    <DIR>          fold10
# 05/20/2014  12:32 AM    <DIR>          fold2
# 05/20/2014  12:33 AM    <DIR>          fold3
# 05/20/2014  12:35 AM    <DIR>          fold4
# 05/20/2014  12:38 AM    <DIR>          fold5
# 05/20/2014  12:39 AM    <DIR>          fold6
# 05/20/2014  12:41 AM    <DIR>          fold7
# 05/20/2014  12:43 AM    <DIR>          fold8
# 05/20/2014  12:45 AM    <DIR>          fold9
#                1 File(s)         24,580 bytes
#               12 Dir(s)  184,789,446,656 bytes free

# %%
### Dog Sound
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
# librosa.display.waveplot(data,sr=sample_rate)
# data, sampling_rate = librosa.load(path)
librosa.display.waveshow(data, sr=sample_rate)
ipd.Audio(filename)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 6
#       3 data,sample_rate=librosa.load(filename)
#       4 # librosa.display.waveplot(data,sr=sample_rate)
#       5 # data, sampling_rate = librosa.load(path)
# ----> 6 librosa.display.waveshow(data, sr=sample_rate)
#       7 ipd.Audio(filename)
#
# File ~\.conda\envs\tensorflow_env\lib\site-packages\librosa\display.py:2042, in waveshow(y, sr, max_points, axis, offset, marker, where, label, transpose, ax, x_axis, **kwargs)
#    2032 axis = rename_kw(
#    2033     old_name="x_axis",
#    2034     old_value=x_axis,
#    (...)
#    2038     version_removed="1.0",
#    2039 )
#    2041 if "color" not in kwargs:
# -> 2042     kwargs.setdefault("color", next(axes._get_lines.prop_cycler)["color"])
#    2044 # Reduce by envelope calculation
#    2045 # this choice of hop ensures that the envelope has at most max_points values
#    2046 hop_length = max(1, y.shape[-1] // max_points)
#
# AttributeError: '_process_plot_var_args' object has no attribute 'prop_cycler'

# %%
import matplotlib.pyplot as plt
import librosa

# Load audio data
data, sample_rate = librosa.load(filename)

# Plot waveform
plt.figure(figsize=(14, 5))
plt.plot(data)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

# %%
# ### Sound
# filename="D:/UrbanSound8K/audio/fold1/7061-6-0-0.wav"
# plt.figure(figsize=(14,5))
# data,sample_rate=librosa.load(filename)
# librosa.display.waveplot(data,sr=sample_rate)
# ipd.Audio(filename)

# %%
import librosa
import matplotlib.pyplot as plt

# Load the audio file
filename = "D:/UrbanSound8K/audio/fold1/7061-6-0-0.wav"
data, sample_rate = librosa.load(filename)

# Plot the waveform
plt.figure(figsize=(14, 5))
plt.plot(data)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[0, 0],
#        [0, 0],
#        [0, 0],
#        ...,
#        [1, 0],
#        [1, 1],
#        [0, 0]], dtype=int16)

# %%
data
# Out:
# array([-7.4505806e-09,  2.9802322e-08,  4.8428774e-08, ...,
#         1.0127544e-05,  2.3271263e-05,  7.0009992e-06], dtype=float32)

# %%
import pandas as pd

metadata=pd.read_csv(r"D:\UrbanSound8K\metadata\UrbanSound8K.csv")
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing
# 5  children_playing
# 6  children_playing
# 7  children_playing
# 8  children_playing
# 9          car_horn

# %%
### Check whether the dataset is imbalanced
metadata['class'].value_counts()
# Out:
# class
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: count, dtype: int64
